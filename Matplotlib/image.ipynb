# %% [markdown]
# # working with Images
#  - reading images
#  - slicing/croping images
#  - image manipultion
#  - saving modified images

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
img=plt.imread("./Matplotlib/pokemon.jpg")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)
#plt.axis('off')
plt.show()

# %%
img.shape #height,width,channel
# Out:
# (183, 275, 3)

# %%
img
# Out:
# array([[[ 79, 102,  92],
#         [ 93, 116, 106],
#         [ 96, 117, 108],
#         ...,
#         [ 26,  31,  27],
#         [ 25,  31,  27],
#         [ 25,  31,  27]],
#
#        [[ 80, 103,  93],
#         [ 90, 113, 103],
#         [ 89, 110, 101],
#         ...,
#         [ 29,  34,  30],
#         [ 28,  34,  30],
#         [ 29,  34,  30]],
#
#        [[ 86, 107,  98],
#         [ 88, 109, 100],
#         [ 80, 101,  92],
#         ...,
#         [ 33,  35,  32],
#         [ 31,  36,  32],
#         [ 33,  35,  32]],
#
#        ...,
#
#        [[ 42,  44,  41],
#         [ 41,  43,  40],
#         [ 41,  43,  40],
#         ...,
#         [ 64,  58,  58],
#         [ 64,  58,  58],
#         [ 64,  58,  58]],
#
#        [[ 45,  47,  44],
#         [ 44,  46,  43],
#         [ 43,  45,  42],
#         ...,
#         [ 62,  56,  56],
#         [ 62,  56,  56],
#         [ 62,  56,  56]],
#
#        [[ 47,  49,  46],
#         [ 46,  48,  45],
#         [ 45,  47,  44],
# ...

# %%
# img [rows,cols,channels]
pikachu_face=img[25:125,50:150,:]

# %%
plt.imshow(pikachu_face)
plt.show()

# %%
img_copy=img.copy()

# %% [markdown]
# creating a bordered image
# - 4 side black border around pikachu image

# %%
row=np.zeros((10,400,3),dtype='int')

# %%
plt.imshow(row)
plt.axis('off')
plt.show()

# %%
img_mod=np.vstack(row,img,row)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Untitled-1.ipynb Cell 15 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000014untitled?line=0'>1</a> img_mod=np.vstack(row,img,row)
#
# File <__array_function__ internals>:4, in vstack(*args, **kwargs)
#
# TypeError: _vhstack_dispatcher() takes 1 positional argument but 3 were given
