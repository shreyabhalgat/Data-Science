# %% [markdown]
# # Scraping an Image

# %%
import requests

# %%
img_url="https://cdn.pixabay.com/photo/2015/04/19/08/33/flower-729512__340.jpg"

# %%
res=requests.get("https://cdn.pixabay.com/photo/2015/04/19/08/33/flower-729512__340.jpg",verify=False)
# Out:
# c:\python 3.9.2\lib\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'cdn.pixabay.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
res.status_code
# Out:
# 200

# %%
res.content
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00\x84\x00\x08\x06\x06\x07\x06\x05\x08\x07\x07\x07\t\t\x08\n\x0c\x14\r\x0c\x0b\x0b\x0c\x19\x12\x13\x0f\x14\x1d\x1a\x1f\x1e\x1d\x1a\x1c\x1c $.\' ",#\x1c\x1c(7),01444\x1f\'9=82<.342\x01\t\t\t\x0c\x0b\x0c\x18\r\r\x182!\x1c!22222222222222222222222222222222222222222222222222\xff\xc2\x00\x11\x08\x01T\x02\x01\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x003y\r\xdb\xeb\xb5\x89k\xa6\x96K\xbaC-\'6*\xaa*\xb2\xb8\xce\xdb+\xd1uZh\xaa]5\xd8\x93\x9a%\x893Y0\x90\xb7\x14gv\x0c\xb1\x92\xe7\xa5\x15kU5\xcd \xac)\xae\x99\xcc]]\xa3\xb6\xda\xac\xad\x8d6\xd4\x14\xd7bFH\x1e\x13Xx\x95kh\x15E\xc8"\xdc\x81\\p!d\xb2\xa8\x0beVjt\xd39\xd1]\xa99TY\x92X\xf1\x9dw\xad\xb6\xeb\xb6\xcalw\x
# ...

# %%
bin_data=res.content

# %%
with open("flower.jgp",'wb')as f:
    f.write(bin_data)
