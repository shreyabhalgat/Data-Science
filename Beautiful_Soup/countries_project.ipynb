# %% [markdown]
# # Beautiful Soup
#
# - used for web Scraping
# - It is a Parser for HTML and XML

# %%
import bs4
import requests
import pandas as pd

# %%
res=requests.get("https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_and_their_capitals_in_native_languages",verify=False)
# Out:
# c:\Users\Shreya\anaconda3\anaconda_app\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'en.wikipedia.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
res.status_code
# Out:
# 200

# %%
text=res.content

# %%
soup=bs4.BeautifulSoup(text)

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of countries and dependencies and their capitals in native languages - Wikipedia</title>
# ...

# %%
soup.title.text
# Out:
# 'List of countries and dependencies and their capitals in native languages - Wikipedia'

# %% [markdown]
# ## Understanding Structure Of HTML

# %%
soup.find('h1').text
# Out:
# 'List of countries and dependencies and their capitals in native languages'

# %%
all_tables=soup.find_all('table')

# %%
len(all_tables)
# Out:
# 32

# %%
all_tables=soup.find_all('table',attrs={"class":"wikitable"})

# %%
len(all_tables) #there is no country name starting from alphabte x hence total 25 tables
# Out:
# 25

# %% [markdown]
# ## Extracting Information of one Country

# %%
all_tables[0] #code of f irst table - A

#understand the structure of table
# Out:
# <table class="wikitable" style="text-align:center;">
# <tbody><tr style="background:#ccc;">
# <th style="width:175px;">Country (<a class="mw-redirect" href="/wiki/Exonym" title="Exonym">exonym</a>)
# </th>
# <th style="width:175px;">Capital (<a class="mw-redirect" href="/wiki/Exonym" title="Exonym">exonym</a>)
# </th>
# <th style="width:175px;">Country (<a class="mw-redirect" href="/wiki/Endonym" title="Endonym">endonym</a>)
# </th>
# <th style="width:175px;">Capital (<a class="mw-redirect" href="/wiki/Endonym" title="Endonym">endonym</a>)
# </th>
# <th style="width:175px;">Official or native language(s) (alphabet/script)
# </th></tr>
# <tr>
# <td><b><a href="/wiki/Afghanistan" title="Afghanistan">Afghanistan</a></b></td>
# <td><a href="/wiki/Kabul" title="Kabul">Kabul</a></td>
# <td><b>Afghanestan</b><br/>افغانستان</td>
# <td><b>Kabul</b><br/>كابل</td>
# ...

# %%
# the first row of each table is header so we need to skip it

# %%
D_table=all_tables[3].find_all("tr")[1:]

# %%
len(D_table)
# Out:
# 4

# %%
D_table
# Out:
# [<tr>
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="387" data-file-width="512" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/9c/Flag_of_Denmark.svg/20px-Flag_of_Denmark.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/9c/Flag_of_Denmark.svg/31px-Flag_of_Denmark.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/9c/Flag_of_Denmark.svg/40px-Flag_of_Denmark.svg.png 2x" width="20"/></span> <b><a href="/wiki/Denmark" title="Denmark">Denmark</a></b></td>
#  <td><a href="/wiki/Copenhagen" title="Copenhagen">Copenhagen</a></td>
#  <td><b>Danmark</b></td>
#  <td><b>København</b></td>
#  <td><a href="/wiki/Danish_language" title="Danish language">Danish</a>
#  </td></tr>,
#  <tr>
# ...

# %%
D_table[1]
# Out:
# <tr>
# <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/34/Flag_of_Djibouti.svg/23px-Flag_of_Djibouti.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/34/Flag_of_Djibouti.svg/35px-Flag_of_Djibouti.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/34/Flag_of_Djibouti.svg/45px-Flag_of_Djibouti.svg.png 2x" width="23"/></span> <b><a href="/wiki/Djibouti" title="Djibouti">Djibouti</a></b></td>
# <td><a href="/wiki/Djibouti_(city)" title="Djibouti (city)">Djibouti</a></td>
# <td><b>Jībūtī</b><br/>جيبوتي<br/><b>Djibouti</b><br/><b>Jabuuti</b><br/><b>Gabuuti</b></td>
# <td><b>Jībūtī</b><br/>جيبوتي<br/><b>Djibouti</b><br/><b>Jabuuti</b><br/><b>Gabuuti</b></td>
# ...

# %%
all_tds=D_table[0].find_all('td')

# %%
len(all_tds)
# Out:
# 5

# %%
all_tds[0].text #countries
# Out:
# ' Denmark'

# %%
all_tds[1].text #capital
# Out:
# 'Copenhagen'

# %% [markdown]
# # Extracting All The Countries

# %%
## Getting information about one table
D_table
# Out:
# [<tr>
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="387" data-file-width="512" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/9c/Flag_of_Denmark.svg/20px-Flag_of_Denmark.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/9c/Flag_of_Denmark.svg/31px-Flag_of_Denmark.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/9c/Flag_of_Denmark.svg/40px-Flag_of_Denmark.svg.png 2x" width="20"/></span> <b><a href="/wiki/Denmark" title="Denmark">Denmark</a></b></td>
#  <td><a href="/wiki/Copenhagen" title="Copenhagen">Copenhagen</a></td>
#  <td><b>Danmark</b></td>
#  <td><b>København</b></td>
#  <td><a href="/wiki/Danish_language" title="Danish language">Danish</a>
#  </td></tr>,
#  <tr>
# ...

# %%
# Creating Empty Dataframe
df=pd.DataFrame({},columns=['Country','Capital','Language'])

# %%
df
# Out:
# Empty DataFrame
# Columns: [Country, Capital, Language]
# Index: []

# %% [markdown]
# ## Getting info from all the tables

# %%
for one_table in all_tables:
    all_rows=one_table.find_all('tr')[1:]
    for tr in all_rows:
        all_tds=tr.find_all('td')
    
        country=all_tds[0].text
        capital=all_tds[1].text
        language=all_tds[-1].text
        
        ele={'country':country,'Capital':capital,'language':language}
        df=df.append(ele,ignore_index=True)
        print(country,capital,language)
        print(" ")
# Out:
# C:\Users\Shreya\AppData\Local\Temp\ipykernel_9992\2831066187.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(ele,ignore_index=True)
# C:\Users\Shreya\AppData\Local\Temp\ipykernel_9992\2831066187.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(ele,ignore_index=True)
# C:\Users\Shreya\AppData\Local\Temp\ipykernel_9992\2831066187.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(ele,ignore_index=True)
# C:\Users\Shreya\AppData\Local\Temp\ipykernel_9992\2831066187.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(ele,ignore_index=True)
# ...

# %%
df
# Out:
#     Country           Capital Language                 country  \
# 0       NaN             Kabul      NaN             Afghanistan
# 1       NaN            Tirana      NaN                 Albania
# 2       NaN           Algiers      NaN                 Algeria
# 3       NaN         Pago Pago      NaN       American Samoa[1]
# 4       NaN  Andorra la Vella      NaN                 Andorra
# ..      ...               ...      ...                     ...
# 237     NaN             Hanoi      NaN                 Vietnam
# 238     NaN          Mata Utu      NaN   Wallis and Futuna[10]
# 239     NaN            Sana'a      NaN                   Yemen
# 240     NaN            Lusaka      NaN                  Zambia
# 241     NaN            Harare      NaN                Zimbabwe
#
#                                               language
# 0                         Pashto/Dari(Arabic script)\n
# 1                                           Albanian\n
# ...

# %%
df.shape
# Out:
# (242, 5)

# %%
# to remove /n from lang column
df["language"]=df["language"].apply(lambda x:x[:-1])

# %% [markdown]
# ## Creating CSV file

# %%
df.to_csv("countries.csv",index=False)

# %% [markdown]
# ## Cleaning CSV

# %%
df
# Out:
#     Country           Capital Language                 country  \
# 0       NaN             Kabul      NaN             Afghanistan
# 1       NaN            Tirana      NaN                 Albania
# 2       NaN           Algiers      NaN                 Algeria
# 3       NaN         Pago Pago      NaN       American Samoa[1]
# 4       NaN  Andorra la Vella      NaN                 Andorra
# ..      ...               ...      ...                     ...
# 237     NaN             Hanoi      NaN                 Vietnam
# 238     NaN          Mata Utu      NaN   Wallis and Futuna[10]
# 239     NaN            Sana'a      NaN                   Yemen
# 240     NaN            Lusaka      NaN                  Zambia
# 241     NaN            Harare      NaN                Zimbabwe
#
#                                               language
# 0                           Pashto/Dari(Arabic script)
# 1                                             Albanian
# ...
