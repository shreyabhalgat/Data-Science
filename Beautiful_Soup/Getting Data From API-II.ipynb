# %%
import requests
import json

# %% [markdown]
# ## Get Public IP Address

# %%
url="https://api.ipify.org"

# %%
res=requests.get("https://api.ipify.org",verify=False)
# Out:
# c:\python 3.9.2\lib\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.ipify.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
res.status_code
# Out:
# 200

# %%
res.text
# Out:
# '103.173.241.51'

# %%
res=requests.get("http://universities.hipolabs.com/search?country=India",verify=False)

# %%
res.text
# Out:
# '[{"domains": ["upes.ac.in"], "web_pages": ["https://www.upes.ac.in/"], "state-province": "Dehradun", "name": "University of Petroleum and Energy Studies", "country": "India", "alpha_two_code": "IN"}, {"domains": ["davietjal.org"], "web_pages": ["http://www.davietjal.org/"], "state-province": "Punjab", "name": "DAV Institute of Engineering & Technology", "country": "India", "alpha_two_code": "IN"}, {"domains": ["lpu.in"], "web_pages": ["http://www.lpu.in/"], "state-province": "Punjab", "name": "Lovely Professional University", "country": "India", "alpha_two_code": "IN"}, {"domains": ["somaiya.edu"], "web_pages": ["https://somaiya.edu/"], "state-province": null, "name": "Somaiya Vidyavihar", "country": "India", "alpha_two_code": "IN"}, {"domains": ["ncuindia.edu"], "web_pages": ["http://www.ncuindia.edu/"], "state-province": "Haryana", "name": "NorthCap University", "country": "India", "alpha_two_code": "IN"}, {"domains": ["ddu.ac.in"], "web_pages": ["http://www.ddu.ac.in/"], "state-p
# ...

# %%
universities=json.loads(res.text)

# %%
universities
# Out:
# [{'domains': ['upes.ac.in'],
#   'web_pages': ['https://www.upes.ac.in/'],
#   'state-province': 'Dehradun',
#   'name': 'University of Petroleum and Energy Studies',
#   'country': 'India',
#   'alpha_two_code': 'IN'},
#  {'domains': ['davietjal.org'],
#   'web_pages': ['http://www.davietjal.org/'],
#   'state-province': 'Punjab',
#   'name': 'DAV Institute of Engineering & Technology',
#   'country': 'India',
#   'alpha_two_code': 'IN'},
#  {'domains': ['lpu.in'],
#   'web_pages': ['http://www.lpu.in/'],
#   'state-province': 'Punjab',
#   'name': 'Lovely Professional University',
#   'country': 'India',
#   'alpha_two_code': 'IN'},
#  {'domains': ['somaiya.edu'],
#   'web_pages': ['https://somaiya.edu/'],
#   'state-province': None,
#   'name': 'Somaiya Vidyavihar',
#   'country': 'India',
#   'alpha_two_code': 'IN'},
#  {'domains': ['ncuindia.edu'],
#   'web_pages': ['http://www.ncuindia.edu/'],
#   'state-province': 'Haryana',
#   'name': 'NorthCap University',
# ...

# %%
len(universities)
# Out:
# 805

# %%
universities[0]
# Out:
# {'domains': ['upes.ac.in'],
#  'web_pages': ['https://www.upes.ac.in/'],
#  'state-province': 'Dehradun',
#  'name': 'University of Petroleum and Energy Studies',
#  'country': 'India',
#  'alpha_two_code': 'IN'}

# %%
universities[1]
# Out:
# {'domains': ['davietjal.org'],
#  'web_pages': ['http://www.davietjal.org/'],
#  'state-province': 'Punjab',
#  'name': 'DAV Institute of Engineering & Technology',
#  'country': 'India',
#  'alpha_two_code': 'IN'}

# %%
req=requests.get("https://api.tvmaze.com/search/shows?q=friends",verify=False)
# Out:
# c:\python 3.9.2\lib\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.tvmaze.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
res.text
# Out:
# '[{"domains": ["upes.ac.in"], "web_pages": ["https://www.upes.ac.in/"], "state-province": "Dehradun", "name": "University of Petroleum and Energy Studies", "country": "India", "alpha_two_code": "IN"}, {"domains": ["davietjal.org"], "web_pages": ["http://www.davietjal.org/"], "state-province": "Punjab", "name": "DAV Institute of Engineering & Technology", "country": "India", "alpha_two_code": "IN"}, {"domains": ["lpu.in"], "web_pages": ["http://www.lpu.in/"], "state-province": "Punjab", "name": "Lovely Professional University", "country": "India", "alpha_two_code": "IN"}, {"domains": ["somaiya.edu"], "web_pages": ["https://somaiya.edu/"], "state-province": null, "name": "Somaiya Vidyavihar", "country": "India", "alpha_two_code": "IN"}, {"domains": ["ncuindia.edu"], "web_pages": ["http://www.ncuindia.edu/"], "state-province": "Haryana", "name": "NorthCap University", "country": "India", "alpha_two_code": "IN"}, {"domains": ["ddu.ac.in"], "web_pages": ["http://www.ddu.ac.in/"], "state-p
# ...

# %%
shows=json.loads(res.text)

# %%
shows
# Out:
# [{'domains': ['upes.ac.in'],
#   'web_pages': ['https://www.upes.ac.in/'],
#   'state-province': 'Dehradun',
#   'name': 'University of Petroleum and Energy Studies',
#   'country': 'India',
#   'alpha_two_code': 'IN'},
#  {'domains': ['davietjal.org'],
#   'web_pages': ['http://www.davietjal.org/'],
#   'state-province': 'Punjab',
#   'name': 'DAV Institute of Engineering & Technology',
#   'country': 'India',
#   'alpha_two_code': 'IN'},
#  {'domains': ['lpu.in'],
#   'web_pages': ['http://www.lpu.in/'],
#   'state-province': 'Punjab',
#   'name': 'Lovely Professional University',
#   'country': 'India',
#   'alpha_two_code': 'IN'},
#  {'domains': ['somaiya.edu'],
#   'web_pages': ['https://somaiya.edu/'],
#   'state-province': None,
#   'name': 'Somaiya Vidyavihar',
#   'country': 'India',
#   'alpha_two_code': 'IN'},
#  {'domains': ['ncuindia.edu'],
#   'web_pages': ['http://www.ncuindia.edu/'],
#   'state-province': 'Haryana',
#   'name': 'NorthCap University',
# ...
