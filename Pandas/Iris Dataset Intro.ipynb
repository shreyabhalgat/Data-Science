# %% [markdown]
# # Iris Dataset -Introduction

# %%
! ls
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
#csv= comma seprated values

# %%
#to load any dataset into pandas
import pandas as pd
import numpy as np
import warnings
iris=pd.read_csv("iris.csv")

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# to get dimenssion of the datset
iris.shape
# Out:
# (150, 5)

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
iris.shape #total 150 rows and 5 columns
# Out:
# (150, 5)

# %%
iris.columns  #names of the columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
#to get the data type of each column
iris.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.describe()

# describe gives statstical outputs
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
#reading particular column here it is species
iris['species']
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
iris['species'].nunique()  #nunique gives number of unique flowers while unique fucntions gives number of unique flowers
# Out:
# 3

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#creating a masking of setosa flowers
#below code gives the list of the all the setosa flowers

iris[iris['species']=='setosa']
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
iris[iris['species']=='setosa'].shape
# Out:
# (50, 5)

# %%
iris['species'].value_counts()
# Out:
# versicolor    50
# virginica     50
# setosa        50
# Name: species, dtype: int64

# %%
iris['sepal_length'].mean()
# Out:
# 5.843333333333334

# %%
iris.sort_values(by="sepal_length")
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 13            4.3          3.0           1.1          0.1     setosa
# 42            4.4          3.2           1.3          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 41            4.5          2.3           1.3          0.3     setosa
# ..            ...          ...           ...          ...        ...
# 122           7.7          2.8           6.7          2.0  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 131           7.9          3.8           6.4          2.0  virginica
#
# [150 rows x 5 columns]

# %%
iris.sort_values(by=["sepal_length","sepal_width"])
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 13            4.3          3.0           1.1          0.1     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 42            4.4          3.2           1.3          0.2     setosa
# 41            4.5          2.3           1.3          0.3     setosa
# ..            ...          ...           ...          ...        ...
# 118           7.7          2.6           6.9          2.3  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 131           7.9          3.8           6.4          2.0  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Grouping Data

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#apply takes another fucntions inside the parameter and apply that particular fucntion on all the rows


iris['species'].apply(len)
# Out:
# 0      6
# 1      6
# 2      6
# 3      6
# 4      6
#       ..
# 145    9
# 146    9
# 147    9
# 148    9
# 149    9
# Name: species, Length: 150, dtype: int64

# %%
len('verginica')
# Out:
# 9

# %%
iris.apply(lambda x:x+x)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width             species
# 0            10.2          7.0           2.8          0.4        setosasetosa
# 1             9.8          6.0           2.8          0.4        setosasetosa
# 2             9.4          6.4           2.6          0.4        setosasetosa
# 3             9.2          6.2           3.0          0.4        setosasetosa
# 4            10.0          7.2           2.8          0.4        setosasetosa
# ..            ...          ...           ...          ...                 ...
# 145          13.4          6.0          10.4          4.6  virginicavirginica
# 146          12.6          5.0          10.0          3.8  virginicavirginica
# 147          13.0          6.0          10.4          4.0  virginicavirginica
# 148          12.4          6.8          10.8          4.6  virginicavirginica
# 149          11.8          6.0          10.2          3.6  virginicavirginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Grouping Data Togethere

# %%
iris.aggregate('min')
# Out:
# sepal_length       4.3
# sepal_width        2.0
# petal_length       1.0
# petal_width        0.1
# species         setosa
# dtype: object

# %%
iris.aggregate(['min','max','mean','median'])
# Out:
#         sepal_length  sepal_width  petal_length  petal_width    species
# min         4.300000        2.000      1.000000     0.100000     setosa
# max         7.900000        4.400      6.900000     2.500000  virginica
# mean        5.843333        3.054      3.758667     1.198667        NaN
# median      5.800000        3.000      4.350000     1.300000        NaN

# %%
groupby=iris.groupby('species')

# %%
 groupby.min()  #group all the species and find min of all
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa               4.3          2.3           1.0          0.1
# versicolor           4.9          2.0           3.0          1.0
# virginica            4.9          2.2           4.5          1.4

# %%
groupby.describe().T
# Out:
# species                setosa  versicolor  virginica
# sepal_length count  50.000000   50.000000  50.000000
#              mean    5.006000    5.936000   6.588000
#              std     0.352490    0.516171   0.635880
#              min     4.300000    4.900000   4.900000
#              25%     4.800000    5.600000   6.225000
#              50%     5.000000    5.900000   6.500000
#              75%     5.200000    6.300000   6.900000
#              max     5.800000    7.000000   7.900000
# sepal_width  count  50.000000   50.000000  50.000000
#              mean    3.418000    2.770000   2.974000
#              std     0.381024    0.313798   0.322497
#              min     2.300000    2.000000   2.200000
#              25%     3.125000    2.525000   2.800000
#              50%     3.400000    2.800000   3.000000
#              75%     3.675000    3.000000   3.175000
#              max     4.400000    3.400000   3.800000
# petal_length count  50.000000   50.000000  50.000000
# ...

# %% [markdown]
# ## Handling Missing Data
#
# - dropna()
# - fillna()

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
warnings.filterwarnings('ignore')
nan_index=np.random.randint(0, 150,20)
nan_index
# Out:
# array([  7, 134,  55,  49,  57,  41,   5,  90,  91, 131,  52,  50, 146,
#        129,  38, 115,  53,  77,  31,  52])

# %%
iris['sepal_length'][nan_index]=np.nan

# %%
iris['sepal_length']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    NaN
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
nan_index=np.random.randint(0, 150,15)
nan_index
iris['petal_width'][nan_index]=np.nan
iris['petal_width']
# Out:
# 0      0.2
# 1      0.2
# 2      0.2
# 3      0.2
# 4      0.2
#       ...
# 145    2.3
# 146    1.9
# 147    2.0
# 148    2.3
# 149    NaN
# Name: petal_width, Length: 150, dtype: float64

# %%
iris.isna().sum()
# Out:
# sepal_length    19
# sepal_width      0
# petal_length     0
# petal_width     27
# species          0
# dtype: int64

# %%
#iris.dropna()  #all rows who have nan values will get dropped
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 142           5.8          2.7           5.1          1.9  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
#
# [106 rows x 5 columns]

# %%
iris['sepal_length'].fillna(value="FILLTHIS")
# Out:
# 0           5.1
# 1           4.9
# 2           4.7
# 3           4.6
# 4           5.0
#          ...
# 145         6.7
# 146    FILLTHIS
# 147         6.5
# 148         6.2
# 149         5.9
# Name: sepal_length, Length: 150, dtype: object

# %%
iris['sepal_length'].mean()
# Out:
# 5.8366412213740455

# %%
iris.isna().sum()
# Out:
# sepal_length    19
# sepal_width      0
# petal_length     0
# petal_width     27
# species          0
# dtype: int64

# %% [markdown]
# ## Concat / Merge DataFrames

# %%
new_df=pd.DataFrame(np.random.randint(0,7,size=(10,4)))

# %%
new_df
# Out:
#    0  1  2  3
# 0  5  1  1  2
# 1  5  2  5  4
# 2  4  2  3  6
# 3  4  3  4  4
# 4  2  1  5  3
# 5  6  1  0  2
# 6  5  5  1  1
# 7  4  2  2  1
# 8  4  4  4  5
# 9  0  5  3  4

# %%
new_df['species']="new-species"

# %%
new_df.head()
# Out:
#    0  1  2  3      species
# 0  5  1  1  2  new-species
# 1  5  2  5  4  new-species
# 2  4  2  3  6  new-species
# 3  4  3  4  4  new-species
# 4  2  1  5  3  new-species

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
new_df.columns=iris.columns

# %%
new_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0             5            1             1            2  new-species
# 1             5            2             5            4  new-species
# 2             4            2             3            6  new-species
# 3             4            3             4            4  new-species
# 4             2            1             5            3  new-species

# %%
pd.concat((iris,new_df))

#axis 0= column wise
# Out:
#     sepal_length  sepal_width  petal_length  petal_width      species
# 0            5.1          3.5           1.4          0.2       setosa
# 1            4.9          3.0           1.4          0.2       setosa
# 2            4.7          3.2           1.3          0.2       setosa
# 3            4.6          3.1           1.5          0.2       setosa
# 4            5.0          3.6           1.4          0.2       setosa
# ..           ...          ...           ...          ...          ...
# 5            6.0          1.0           0.0          2.0  new-species
# 6            5.0          5.0           1.0          1.0  new-species
# 7            4.0          2.0           2.0          1.0  new-species
# 8            4.0          4.0           4.0          5.0  new-species
# 9            0.0          5.0           3.0          4.0  new-species
#
# [160 rows x 5 columns]

# %% [markdown]
# # Conclusions
#
# 1. Total number of rows/Data Points =150
# 2. Total Number of Columns=5
# 3. There are total three unique species/flowers namely
#     1. setosa
#     2. versicolor
#     3. virginica
# 4. There are total 50 flowers each of versicolor,setosa and Virginica
